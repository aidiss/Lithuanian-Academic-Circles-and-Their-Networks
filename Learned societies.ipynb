# %%
import pandas as pd

# %% [markdown]
# interesting (http://www.filosofai.lt/?page_id=23)
#
#
# Prezidentė – dr. Audronė Žukauskaitė,
# Viceprezidentas – doc. Naglis Kardelis,
# Sekretorius – lekt. Vilius Dranseika.
#
# Valdyba:
# stud. Simas Čelutka (VU),
# doc. Jonas Dagys (VU),
# lekt. Vilius Dranseika (VU),
# doc. Aldis Gedutis (KU),
# doc. Naglis Kardelis (VU/LKTI),
# prof. Gintautas Mažeikis (VDU),
# doc. Arūnas Mickevičius (VU),
# doc. Nerijus Milerius (VU),
# prof. Rita Šerpytytė (VU),
# dokt. Julija Tuleikytė (VU),
# dr. Audronė Žukauskaitė (LKTI)
#
# Parašyti skriptą, kuris per google ieškotų asociacijų, draugijų ir pan.

# %% [markdown]
# Kokias institucijas iš vis žinome?

# %% [markdown]
# Pradėkime sąrašą.

# %%
ak_as_sarasas = [ u'Lietuvos filosofų draugija',
                 u'Asociacija "Šviesuva"',
 u'Anesteziologijos klubas',
 u'Lietuvos dirvožemininkų draugija prie Lietuvos MA Žemės ūkio ir miškų skyriaus',
 u'Lietuvos mokslo istorikų ir filosofų bendrija',
 u'Asociacija "Academia Salensis"',
 u'Energetikos ekonomikos asoaciacija',
 u'Lietuvos ekonomistų asociacija',
 u'Lietuvos geoterimos asociacija',
 u'Lietuvos kartografų draugija',
 u'BASNET Forumas',
 u'Lietuvos biotechnologų asociacija',
 u'Lietuvos matematikų draugija',
 u'Lietuvos katalikų mokslo akademija',
 u'Lietuvos fizikų draugija',
 u'Baltijos labaratorinių gyvūnų mokslo asociacija',
 u'Lietuvos kriminologų asociacija',
 u'Lietuvos lazerių asociacija',
 u'Klasikų asociacija',
 u'Lietuvos operacijų tyrimo draugija',

 u'Lietuvos neuromokslų asociacija',
 u'Lietuvos fiziologų draugija',
 u'Lietuvos kompiuterininkų sąjunga',
 u'Lietuvos lyginamosios literatūros asociacija',
 u'Lietuvos politologų asociacija',
 u'Lietuvos universitetų tęstinių studijų institucijų asociacija',
 u'Lietuvos biochemikų draugija',
 u'Lietuvos geografų draugija',
 u'Lietuvos mokslo periodikos asociacija',
 u'Lietuvos jaunųjų mokslinknų sąjunga'
 ]

# %%
df = pd.DataFrame(index=ak_as_sarasas,columns=['disciplinary', 'dsc_art','dsc_kds',
                                               'vns_va','vns_va_vice', 'skr',
                                               'klg_va',
                                               'url',
                                               'tikslas','vizija','misija'])

# %% [markdown]
# Daugiau apie tai, kas kiek paramos gavo

# %% [markdown]
# (http://www.lmt.lt/lt/mkf/parama/aco/aco-rezultatai.html)
# (http://www.lmt.lt/lt/mkf/parama/aco/aco-rezultatai/aco-2011.html)
# (http://www.lmt.lt/lt/mkf/parama/aco/aco-rezultatai/aco-2011-ii-kv.html)
# (http://www.lmt.lt/lt/mkf/parama/aco/aco-rezultatai/aco-2012-i-rezultatai.html)
# (http://www.lmt.lt/lt/mkf/parama/aco/aco-rezultatai/aco-2013-i-rezultatai.html)
# (http://www.lmt.lt/lt/mkf/parama/aco/aco-rezultatai/aco-2014-i-rezultatai.html)

# %%
df.T[u'Lietuvos filosofų draugija'].disciplinary = True
df.T[u'Lietuvos filosofų draugija'].dsc_art = u'filosofija'
df.T[u'Lietuvos filosofų draugija'].vns_va = u'Audronė Žukauskaitė'
df.T[u'Lietuvos filosofų draugija'].vns_va_vice = u'Naglis Kardelis'
df.T[u'Lietuvos filosofų draugija'].skr = u'Vilius Dranseika'

thedict = [{'prg': 'stud', 'vrd': u'Simas Čelutka', 'ins':'VU'},
{'prg': 'doc', 'vrd': u'Jonas Dagys', 'ins':'VU'},
{'prg': 'lekt', 'vrd':u'Vilius Dranseika', 'ins':'VU'},
{'prg': 'doc', 'vrd':u'Aldis Gedutis', 'ins':'KU'},
{'prg': 'doc', 'vrd':u'Naglis Kardelis', 'ins':['VU','LKTI']},
{'prg': 'prof', 'vrd':u'Gintautas Mažeikis', 'ins':'VDU'},
{'prg': 'doc', 'vrd':u'Arūnas Mickevičius', 'ins':'VU'},
{'prg': 'doc', 'vrd':u'Nerijus Milerius', 'ins':'VU'},
{'prg': 'prof', 'vrd':u'Rita Šerpytytė', 'ins':'VU'},
{'prg': 'dokt', 'vrd':u'Julija Tuleikytė', 'ins':'VU'},
{'prg': 'dr', 'vrd':u'Audronė Žukauskaitė', 'ins':'LKTI'}]
df.T[u'Lietuvos filosofų draugija'].klg_va = thedict

df.T[u'Lietuvos filosofų draugija']
# Out:
# disciplinary                                                 True
# dsc_art                                                filosofija
# dsc_kds                                                       NaN
# vns_va                                        Audronė Žukauskaitė
# vns_va_vice                                       Naglis Kardelis
# skr                                              Vilius Dranseika
# klg_va          [{u'prg': u'stud', u'ins': u'VU', u'vrd': u'Si...
# url                                                           NaN
# tikslas                                                       NaN
# vizija                                                        NaN
# misija                                                        NaN
# Name: Lietuvos filosofų draugija, dtype: object

# %%
df.ix[u'Lietuvos fizikų draugija']['disciplinary'] = True
df.ix[u'Anesteziologijos klubas']['disciplinary'] = True
df.ix[u'Energetikos ekonomikos asoaciacija']['disciplinary'] = True
df.ix[u'Lietuvos biotechnologų asociacija']['disciplinary'] = True
df.ix[u'Lietuvos matematikų draugija']['disciplinary'] = True
df.ix[u'Lietuvos neuromokslų asociacija']['disciplinary'] = True
df.ix[u'Lietuvos politologų asociacija']['disciplinary'] = True
df.ix[u'Lietuvos kriminologų asociacija']['disciplinary'] = True
df.ix[u'Lietuvos biochemikų draugija']['disciplinary'] = True
df.ix[u'Lietuvos geografų draugija']['disciplinary'] = True
df.ix[u'Lietuvos lyginamosios literatūros asociacija']['disciplinary'] = True

# %%
#pd.concat(df, u'Lietuvos fenomenologų asociacija')
#df.T.append(u'Lietuvos fenomenologų asociacija',ignore_index=True)

# %% [markdown]
# Ką galime pasakyti apie šias institucijas? Ne visos jos gali būti ištirtos, duomenų apie jas tikrai ne visada rasime. Tačiau, duomenų yra, ir rinkdami tai, ką galime rasti LMT ir šių asociacijų puslapiuose bei paskyrose galime atrasti įvairius tinklus.

# %%
URL = 'lmt\parame akad asoc_kvietimas ar rezultatai.xlsx'
df1 = pd.io.excel.read_excel(URL, 'pateike', header=0, skiprows = None, index_col = None)
df2 = pd.io.excel.read_excel(URL, 'laimeje', header=0, skiprows = None, index_col = None)

# %%
#add some more entries. It is all about PDFS.

# %%
df
# Out:
#                                                                                disciplinary  \
# Lietuvos filosofų draugija                                                             True
# Asociacija "Šviesuva"                                                                   NaN
# Anesteziologijos klubas                                                                True
# Lietuvos dirvožemininkų draugija prie Lietuvos MA Žemės ūkio ir miškų skyriaus          NaN
# Lietuvos mokslo istorikų ir filosofų bendrija                                           NaN
# Asociacija "Academia Salensis"                                                          NaN
# Energetikos ekonomikos asoaciacija                                                     True
# Lietuvos ekonomistų asociacija                                                          NaN
# Lietuvos geoterimos asociacija                                                          NaN
# ...
